# %% [markdown]
# # Exploring the original different files of datasets

# %%
import pandas as pd

# %% [markdown]
# ### Exploring file:
# - PS_LibreAcces_201902201107/PS_LibreAcces_Personne_activite_201902200830
#
# note : (registered as txt but CSV with seperator = |)

# %%
person_activity_df = pd.read_csv('../data/external/PS_LibreAcces_201902201107/PS_LibreAcces_Personne_activite_201902200830.txt',
                                   sep='|', header='infer', dtype='str',
                                   encoding='UTF-8',)

# %%
# Change the settings so pandas can display up to 55 columns
pd.set_option('display.max_columns', 55)

# %%
person_activity_df.head()
# Out:
#   Type d'identifiant PP Identifiant PP Identification nationale PP  \
# 0                     0      012600409                  0012600409
# 1                     0      012802732                  0012802732
# 2                     0      012803193                  0012803193
# 3                     0      012803532                  0012803532
# 4                     0      012804175                  0012804175
#
#   Code civilité d'exercice Libellé civilité d'exercice Code civilité  \
# 0                      NaN                         NaN             M
# 1                      NaN                         NaN             M
# 2                      NaN                         NaN           MME
# 3                      NaN                         NaN          MLLE
# 4                      NaN                         NaN          MLLE
#
#   Libellé civilité Nom d'exercice Prénom d'exercice Code profession  \
# 0         Monsieur           BOCH            DAMIEN              26
# ...

# %%
person_activity_df.shape
# Out:
# (1708383, 53)

# %%
# Count how many doctors is there in the database (code profession = 10)
person_activity_df.loc[personne_activite_df["Code profession"] == '10'].shape[0]
# Out:
# 409902

# %%
doctors_df = personne_activite_df.loc[personne_activite_df["Code profession"] == '10']

# %%
doctors_df['Libellé mode exercice'].value_counts()
# Out:
# Libéral     191666
# Salarié     143206
# Bénévole       270
# Name: Libellé mode exercice, dtype: int64

# %%
doctors_df.groupby('Libellé mode exercice').count()
# Out:
#                        Type d'identifiant PP  Identifiant PP  \
# Libellé mode exercice
# Bénévole                                 270             270
# Libéral                               191666          191666
# Salarié                               143206          143206
#
#                        Identification nationale PP  Code civilité d'exercice  \
# Libellé mode exercice
# Bénévole                                       270                       270
# Libéral                                     191666                    180542
# Salarié                                     143206                    142814
#
#                        Libellé civilité d'exercice  Code civilité  \
# Libellé mode exercice
# Bénévole                                       270            270
# Libéral                                     180542         191666
# Salarié                                     142814         143206
#
# ...

# %%
doctors_df.duplicated('Identification nationale PP').value_counts()
# Out:
# False    315073
# True      94829
# dtype: int64

# %%
doctors_df['Identification nationale PP'].value_counts()
# Out:
# 810101410198    27
# 810100298818    27
# 810002205937    25
# 810002294618    25
# 810001855310    22
# 810100580579    21
# 810100273324    19
# 810002473824    19
# 810100769800    19
# 810002185998    18
# 810002150141    18
# 810100078350    18
# 810002149713    18
# 810004085873    18
# 810002151750    18
# 810002150182    18
# 810100623759    18
# 810002180007    18
# 810100812618    18
# 810002482668    18
# 810100472488    18
# 810002168259    18
# 810002479185    18
# 810100078459    18
# 810003791323    18
# 810003942850    18
# 810002149135    18
# 810002149945    18
# 810100074060    18
# 810003822276    18
#                 ..
# 810001516946     1
# 810003032959     1
# 810002079340     1
# 810100196590     1
# 810002925252     1
# 810004028279     1
# 810004891429     1
# 810100208361     1
# 810003247938     1
# 810003233961     1
# 810002713674     1
# 810004411483     1
# 810002307626     1
# 810004089057     1
# 810003150405     1
# 810003815049     1
# ...

# %%
doctors_df['Identification nationale PP'].value_counts().value_counts()
# Out:
# 1     257326
# 2      40250
# 3       9885
# 4       3399
# 5       1473
# 6        888
# 8        705
# 7        539
# 9        196
# 10       159
# 11        75
# 12        73
# 18        35
# 13        33
# 14        22
# 15         3
# 16         3
# 19         3
# 25         2
# 27         2
# 21         1
# 22         1
# Name: Identification nationale PP, dtype: int64

# %%
doctors_df.groupby(['revenue','session','user_id'])['user_id'].count()

# %%
doctors_df.groupby(['Identification nationale PP',"Nom d'exercice"]).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-908d14b0a2cb> in <module>
# ----> 1 doctors_df.groupby(['Identification nationale PP',"Nom d'exercice"]).value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
# --> 765                              (type(self).__name__, attr))
#     766
#     767     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
doctors_df.loc[doctors_df['Identification nationale PP'] == '810101410198']
# Out:
#         Type d'identifiant PP Identifiant PP Identification nationale PP  \
# 86104                       8    10101410198                810101410198
# 265875                      8    10101410198                810101410198
# 279121                      8    10101410198                810101410198
# 305923                      8    10101410198                810101410198
# 525807                      8    10101410198                810101410198
# 539164                      8    10101410198                810101410198
# 652827                      8    10101410198                810101410198
# 766110                      8    10101410198                810101410198
# 819539                      8    10101410198                810101410198
# 819540                      8    10101410198                810101410198
# 899692                      8    10101410198                810101410198
# 912978                      8    10101410198                810101410198
# ...

# %%
doctors_df810101410198
